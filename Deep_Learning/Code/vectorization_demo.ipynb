# %%
import numpy as np
import time

# %%
a = np.random.rand(1000000)
b = np.random.rand(1000000)

tic = time.time()
c = np.dot(a, b)
toc = time.time()

print(c)
print("Vectorized version: " + str(1000*(toc-tic)) + "ms ")

c = 0
tic = time.time()
for i in range(1000000):
    c += a[i]*b[i]
toc = time.time()

print(c)
print("For loop: " + str(1000*(toc-tic)) + "ms ")
# Out:
# 250008.67997537085
# Vectorized version: 2.727031707763672ms
# 250008.67997537408
# For loop: 511.75427436828613ms
